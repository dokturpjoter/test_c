# %%
from Web_cohortizer_D_4_www_ready import *

# %%
plot_network(series[str(0.02)][str(2)])
# Out:
# /srv/conda/envs/kernel/lib/python2.7/site-packages/networkx/drawing/nx_pylab.py:522: MatplotlibDeprecationWarning: The is_string_like function was deprecated in version 2.1.
#   if not cb.is_string_like(edge_color) \
# /srv/conda/envs/kernel/lib/python2.7/site-packages/networkx/drawing/nx_pylab.py:543: MatplotlibDeprecationWarning: The is_string_like function was deprecated in version 2.1.
#   if cb.is_string_like(edge_color) or len(edge_color) == 1:

# %%
from ipywidgets import interact
from ipywidgets.widgets import IntSlider, Dropdown

# %%
def plot_data(ii):
    rho = '0.0' + str(ii)
    plot_network(series[rho][str(2)]) 
    #plot_network(series[str(0.02)][str(2)]) 
    
p = interact(plot_data, ii=IntSlider(0, 1, 10))
# Out:
# aW50ZXJhY3RpdmUoY2hpbGRyZW49KEludFNsaWRlcih2YWx1ZT0xLCBkZXNjcmlwdGlvbj11J2lpJywgbWF4PTEwLCBtaW49MSksIE91dHB1dCgpKSwgX2RvbV9jbGFzc2VzPSh1J3dpZGdldC3igKY=
